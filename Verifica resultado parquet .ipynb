# %%
import pandas as pd

# %%
df = pd.read_parquet('data/conekta-00000-of-00001')
df.head()
# Out:
#                                          id company_name  \
# 0  48ba4bdbfb56ceebb32f2bd0263e759be942af3d   MiPasajefy
# 1  05fc6f5ac66b6ee7e4253aa5d0c2299eb47aaaf4   MiPasajefy
# 2  2cdce231c1fc6a2061bfa2f1d978351fe217245d   MiPasajefy
# 3  81633ba310a50b673efd469c37139576982901aa   MiPasajefy
# 4  6ccfc4c24e788e4bca448df343698782db6b0c0b   MiPasajefy
#
#                                  company_id      amount           status  \
# 0  cbf1c8b09cd5b549416d49d220a40cbd317f952e    3.000000           voided
# 1  cbf1c8b09cd5b549416d49d220a40cbd317f952e    3.000000  pending_payment
# 2  cbf1c8b09cd5b549416d49d220a40cbd317f952e    3.000000           voided
# 3  cbf1c8b09cd5b549416d49d220a40cbd317f952e  102.610001             paid
# 4  cbf1c8b09cd5b549416d49d220a40cbd317f952e  184.490005             paid
#
#    created_at  updated_at
# 0  2019-03-19
# 1  2019-05-06
# 2  2019-02-22
# 3  2019-02-27  2019-02-27
# 4  2019-02-05  2019-02-05

# %%
df.describe()
# Out:
#             amount
# count  9997.000000
# mean           inf
# std            NaN
# min       2.990000
# 25%      31.209999
# 50%      60.610001
# 75%     109.620003
# max            inf
